# %%
from test import EigenData
import numpy as np
import scipy.io
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import torch
# %matplotlib inline

# %%
data = EigenData()
eigenworms = data.get_eigenworms('EigenWorms.mat')

footage = data.get_footage('20150814-All-PNAS2011-DataStitched .mat')
newdata = torch.rand(33600,5)
for k in footage.keys():
    print(k, footage[k].shape)
    arr1=footage[k]

    arr2=arr1[:5,]

    r = data.reconstruct(footage[k])
    print('-->', r.shape)
    dataset1 = arr2.transpose()

    newdata = np.concatenate((newdata,dataset1),axis=0)
newdata = newdata[33600:,]
print(newdata.shape)
# Out:
# b (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# c (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# d (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# e (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# f (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# g (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# h (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# i (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# j (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# k (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# l (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# m (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# (403200, 5)

# %%
first_5_eigenworms = eigenworms[0:5,:]
eig_worm_0 = eigenworms[0,:]
eig_worm_1 = eigenworms[1,:]
eig_worm_2 = eigenworms[2,:]
eig_worm_3 = eigenworms[3,:]
eig_worm_4 = eigenworms[4,:]

# %%
data1=newdata[~np.isnan(newdata).any(axis=1)]
#d[:,~np.all(np.isnan(d), axis=0)]
#data3=footage[k].flatten()
data1 = data1.astype('float32')
print(data1.shape)
print(len(data1))
# Out:
# (386422, 5)
# 386422

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data1 = scaler.fit_transform(data1)

# %%
def create_dataset(dataset, look_back=10):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
data_X, data_Y = create_dataset(data1)

print(data_X.shape)
print(data_Y.shape)
# Out:
# (386412, 10, 5)
# (386412, 5)

# %%
train_size = int(len(data_X) * 0.8)
test_size = len(data_X) - train_size
train_X = data_X[:train_size]
train_Y = data_Y[:train_size]
test_X = data_X[train_size:]
test_Y = data_Y[train_size:]

print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (309129, 10, 5)
# (309129, 5)
# (77283, 10, 5)
# (77283, 5)

# %%
# reshape input to be [samples, time steps, features]
train_X = np.reshape(train_X, (train_X.shape[0], 10, train_X.shape[2]))
test_X = np.reshape(test_X, (test_X.shape[0], 10, test_X.shape[2]))

print(train_X.shape)
print(train_Y.shape)
# Out:
# (309129, 10, 5)
# (309129, 5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Input,LSTM,Dropout,Dense


timesteps = 10
# create and fit the LSTM network

model = keras.Sequential()
model.add(LSTM(200,input_shape=(timesteps,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200,input_shape=(timesteps,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200,input_shape=(timesteps,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200,input_shape=(timesteps,5),return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(5,activation='linear'))
model.compile(optimizer='rmsprop',loss='mean_squared_error',metrics=['accuracy','mape'])

# %%
history = model.fit(train_X, train_Y, epochs=100, batch_size=500, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/100
# 495/495 - 241s - loss: 0.0205 - accuracy: 0.5553 - mape: 791.1140 - val_loss: 0.0025 - val_accuracy: 0.7779 - val_mape: 635.3670
# Epoch 2/100
# 495/495 - 237s - loss: 0.0029 - accuracy: 0.8499 - mape: 359.0639 - val_loss: 0.0014 - val_accuracy: 0.9075 - val_mape: 375.9336
# Epoch 3/100
# 495/495 - 242s - loss: 0.0017 - accuracy: 0.8842 - mape: 104.7719 - val_loss: 0.0017 - val_accuracy: 0.9243 - val_mape: 157.0526
# Epoch 4/100
# 495/495 - 241s - loss: 0.0013 - accuracy: 0.8965 - mape: 244.4153 - val_loss: 0.0011 - val_accuracy: 0.9207 - val_mape: 193.3614
# Epoch 90/100
# 495/495 - 165s - loss: 1.8860e-04 - accuracy: 0.9521 - mape: 103.1031 - val_loss: 4.8437e-05 - val_accuracy: 0.9738 - val_mape: 86.5450
# Epoch 91/100
# 495/495 - 160s - loss: 1.8785e-04 - accuracy: 0.9527 - mape: 35.4195 - val_loss: 6.4572e-05 - val_accuracy: 0.9764 - val_mape: 85.3338
# Epoch 92/100
# 495/495 - 161s - loss: 1.8717e-04 - accuracy: 0.9522 - mape: 83.2376 - val_loss: 3.3438e-05 - val_accuracy: 0.9812 - val_mape: 84.6070
# Epoch 93/100
# 495/495 - 157s - loss: 1.8685e-04 - accuracy: 0.9522 - mape: 62.9907 - val_loss: 4.3044e-05 - val_accuracy: 0.9700 - val_mape: 144.0389
# Epoch 94/100
# 495/495 - 159s - loss: 1.8644e-04 - accuracy: 0.9525 - mape: 44.0646 - val_loss: 7.4256e-05 - val_accuracy: 0.9582 - val_mape: 114.1703
# Epoch 95/100
# 495/495 - 158s - loss: 1.8621e-04 - accuracy: 0.9526 - mape: 40.4045 - val_loss: 4.0711e-05 - val_accuracy: 0.9813 - val_mape: 97.6698
# Epoch 96/100
# 495/495 - 156s - loss: 1.8547e-04 - accuracy: 0.9526 - mape: 102.0783 - val_loss: 6.3636e-05 - val_accuracy: 0.9746 - val_mape: 59.6457
# Epoch 97/100
# 495/495 - 157s - loss: 1.8515e-04 - accuracy: 0.9533 - mape: 115.5304 - val_loss: 4.1459e-05 - val_accuracy: 0.9801 - val_mape: 164.5749
# Epoch 98/100
# 495/495 - 159s - loss: 1.8471e-04 - accuracy: 0.9520 - mape: 68.8711 - val_loss: 4.6902e-05 - val_accuracy: 0.9777 - val_mape: 142.1862
# Epoch 99/100
# 495/495 - 158s - loss: 1.8460e-04 - accuracy: 0.9530 - mape: 93.2003 - val_loss: 4.8175e-05 - val_accuracy: 0.9673 - val_mape: 81.6302
# Epoch 100/100
# 495/495 - 161s - loss: 1.8384e-04 - accuracy: 0.9522 - mape: 92.3684 - val_loss: 4.9662e-05 - val_accuracy: 0.9795 - val_mape: 71.0532

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 10, 200)           164800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10, 200)           0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 10, 200)           320800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10, 200)           0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 10, 200)           320800
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 200)           0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 200)               320800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 1005
# =================================================================
# Total params: 1,128,205
# Trainable params: 1,128,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=range(len(history.history['loss']))
plt.figure()
plt.plot(epochs,history.history['loss'],'b',label='Training loss')
plt.plot(epochs,history.history['val_loss'],'r',label='Validation val_loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
epochs=range(len(history.history['accuracy']))
plt.figure()
plt.plot(epochs,history.history['accuracy'],'b',label='Training accuracy')
plt.plot(epochs,history.history['val_accuracy'],'r',label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.show()

# %%
epochs=range(len(history.history['mape']))
plt.figure()
plt.plot(epochs,history.history['mape'],'b',label='Training mape')
plt.plot(epochs,history.history['val_mape'],'r',label='Validation mape')
plt.title('Training and Validation mape')
plt.legend()
plt.show()

# %%
trainPredict = model.predict(train_X)
testPredict = model.predict(test_X)

# %%
print(testPredict.shape)
print(trainPredict.shape)
print(test_Y.shape)
# Out:
# (77283, 5)
# (309129, 5)
# (77283, 5)

# %%
length = 2500
vmin = -0.65
vmax = 0.35
#3300
start = 5000
slc = slice(start,start+length)
start_of_test = 309133

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("EigenMode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,length])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,20
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode")
    plt.show()
plot_coefficient_reconstruction(model, test_X[start:start+length], test_Y[start:start+length])

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("Mode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,38642])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,10
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode Reconstruction")
    plt.show()
plot_coefficient_reconstruction(model, test_X, test_Y)
