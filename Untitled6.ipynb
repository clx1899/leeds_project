# %%
from test import EigenData
import numpy as np
import scipy.io
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import torch
# %matplotlib inline

# %%
data = EigenData()
eigenworms = data.get_eigenworms('EigenWorms.mat')

footage = data.get_footage('20150814-All-PNAS2011-DataStitched .mat')
newdata = torch.rand(33600,5)
for k in footage.keys():
    print(k, footage[k].shape)
    arr1=footage[k]

    arr2=arr1[:5,]

    r = data.reconstruct(footage[k])
    print('-->', r.shape)
    dataset1 = arr2.transpose()

    newdata = np.concatenate((newdata,dataset1),axis=0)
newdata = newdata[33600:,]
print(newdata.shape)
# Out:
# b (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# c (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# d (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# e (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# f (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# g (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# h (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# i (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# j (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# k (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# l (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# m (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# (403200, 5)

# %%
first_5_eigenworms = eigenworms[0:5,:]
eig_worm_0 = eigenworms[0,:]
eig_worm_1 = eigenworms[1,:]
eig_worm_2 = eigenworms[2,:]
eig_worm_3 = eigenworms[3,:]
eig_worm_4 = eigenworms[4,:]

# %%
data1=newdata[~np.isnan(newdata).any(axis=1)]
#d[:,~np.all(np.isnan(d), axis=0)]
#data3=footage[k].flatten()
data1 = data1.astype('float32')
print(data1.shape)
print(len(data1))
# Out:
# (386422, 5)
# 386422

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data1 = scaler.fit_transform(data1)

# %%
def create_dataset(dataset, look_back=5):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
data_X, data_Y = create_dataset(data1)

print(data_X.shape)
print(data_Y.shape)
# Out:
# (386417, 5, 5)
# (386417, 5)

# %%
train_size = int(len(data_X) * 0.8)
test_size = len(data_X) - train_size
train_X = data_X[:train_size]
train_Y = data_Y[:train_size]
test_X = data_X[train_size:]
test_Y = data_Y[train_size:]

print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (309133, 5, 5)
# (309133, 5)
# (77284, 5, 5)
# (77284, 5)

# %%
# reshape input to be [samples, time steps, features]
train_X = np.reshape(train_X, (train_X.shape[0], 5, train_X.shape[2]))
test_X = np.reshape(test_X, (test_X.shape[0], 5, test_X.shape[2]))

print(train_X.shape)
print(train_Y.shape)
# Out:
# (309133, 5, 5)
# (309133, 5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Input,LSTM,Dropout,Dense



# create and fit the LSTM network

model = keras.Sequential()
model.add(LSTM(300,input_shape=(5,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(300,input_shape=(5,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(300,input_shape=(5,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(300,input_shape=(5,5),return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(5,activation='linear'))
model.compile(optimizer='rmsprop',loss='mean_squared_error',metrics=['accuracy','mape'])

# %%
history = model.fit(train_X, train_Y, epochs=100, batch_size=500, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/100
# 495/495 - 149s - loss: 0.0117 - accuracy: 0.6257 - mape: 616.4173 - val_loss: 0.0043 - val_accuracy: 0.7453 - val_mape: 611.5922
# Epoch 2/100
# 495/495 - 142s - loss: 0.0030 - accuracy: 0.8415 - mape: 356.0426 - val_loss: 9.0742e-04 - val_accuracy: 0.8817 - val_mape: 266.0565
# Epoch 3/100
# 495/495 - 142s - loss: 0.0018 - accuracy: 0.8833 - mape: 138.5515 - val_loss: 9.2413e-04 - val_accuracy: 0.8926 - val_mape: 75.3999
# Epoch 4/100
# 495/495 - 140s - loss: 1.6669e-04 - accuracy: 0.9546 - mape: 32.0020 - val_loss: 5.9530e-05 - val_accuracy: 0.9681 - val_mape: 84.8444
# Epoch 90/100
# 495/495 - 139s - loss: 1.6564e-04 - accuracy: 0.9550 - mape: 41.0959 - val_loss: 5.5957e-05 - val_accuracy: 0.9781 - val_mape: 57.1388
# Epoch 91/100
# 495/495 - 142s - loss: 1.6549e-04 - accuracy: 0.9553 - mape: 75.2285 - val_loss: 7.2540e-05 - val_accuracy: 0.9789 - val_mape: 129.1104
# Epoch 92/100
# 495/495 - 142s - loss: 1.6518e-04 - accuracy: 0.9554 - mape: 115.0149 - val_loss: 4.8647e-05 - val_accuracy: 0.9793 - val_mape: 50.3109
# Epoch 93/100
# 495/495 - 142s - loss: 1.6437e-04 - accuracy: 0.9555 - mape: 61.6817 - val_loss: 3.9653e-05 - val_accuracy: 0.9817 - val_mape: 45.2366
# Epoch 94/100
# 495/495 - 142s - loss: 1.6429e-04 - accuracy: 0.9561 - mape: 79.8653 - val_loss: 3.5972e-05 - val_accuracy: 0.9817 - val_mape: 96.4925
# Epoch 95/100
# 495/495 - 141s - loss: 1.6323e-04 - accuracy: 0.9559 - mape: 125.1045 - val_loss: 7.1080e-05 - val_accuracy: 0.9760 - val_mape: 78.1312
# Epoch 96/100
# 495/495 - 141s - loss: 1.6301e-04 - accuracy: 0.9558 - mape: 113.3195 - val_loss: 5.1175e-05 - val_accuracy: 0.9670 - val_mape: 62.0700
# Epoch 97/100
# 495/495 - 145s - loss: 1.6234e-04 - accuracy: 0.9558 - mape: 100.7768 - val_loss: 4.0740e-05 - val_accuracy: 0.9767 - val_mape: 93.6773
# Epoch 98/100
# 495/495 - 139s - loss: 1.6162e-04 - accuracy: 0.9557 - mape: 83.5042 - val_loss: 7.9971e-05 - val_accuracy: 0.9723 - val_mape: 126.5744
# Epoch 99/100
# 495/495 - 141s - loss: 1.6165e-04 - accuracy: 0.9562 - mape: 79.8804 - val_loss: 5.1401e-05 - val_accuracy: 0.9727 - val_mape: 65.6115
# Epoch 100/100
# 495/495 - 142s - loss: 1.6100e-04 - accuracy: 0.9557 - mape: 149.2301 - val_loss: 4.6065e-05 - val_accuracy: 0.9668 - val_mape: 89.9376

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 300)            367200
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 300)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 300)            721200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 300)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 300)            721200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 300)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 300)               721200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 1505
# =================================================================
# Total params: 2,532,305
# Trainable params: 2,532,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=range(len(history.history['loss']))
plt.figure()
plt.plot(epochs,history.history['loss'],'b',label='Training loss')
plt.plot(epochs,history.history['val_loss'],'r',label='Validation val_loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
epochs=range(len(history.history['accuracy']))
plt.figure()
plt.plot(epochs,history.history['accuracy'],'b',label='Training accuracy')
plt.plot(epochs,history.history['val_accuracy'],'r',label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.show()

# %%
epochs=range(len(history.history['mape']))
plt.figure()
plt.plot(epochs,history.history['mape'],'b',label='Training mape')
plt.plot(epochs,history.history['val_mape'],'r',label='Validation mape')
plt.title('Training and Validation mape')
plt.legend()
plt.show()

# %%
trainPredict = model.predict(train_X)
testPredict = model.predict(test_X)

# %%
print(testPredict.shape)
print(trainPredict.shape)
print(test_Y.shape)
# Out:
# (77284, 5)
# (309133, 5)
# (77284, 5)

# %%
length = 2500
vmin = -0.65
vmax = 0.35
#3300
start = 5000
slc = slice(start,start+length)
start_of_test = 309133

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("EigenMode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,length])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,20
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode")
    plt.show()
plot_coefficient_reconstruction(model, test_X[start:start+length], test_Y[start:start+length])

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("Mode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,38642])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,10
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode Reconstruction")
    plt.show()
plot_coefficient_reconstruction(model, test_X, test_Y)
