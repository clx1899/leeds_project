# %%
from test import EigenData
import numpy as np
import scipy.io
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import torch
# %matplotlib inline

# %%
data = EigenData()
eigenworms = data.get_eigenworms('EigenWorms.mat')

footage = data.get_footage('20150814-All-PNAS2011-DataStitched .mat')
newdata = torch.rand(33600,5)
for k in footage.keys():
    print(k, footage[k].shape)
    arr1=footage[k]

    arr2=arr1[:5,]

    r = data.reconstruct(footage[k])
    print('-->', r.shape)
    dataset1 = arr2.transpose()

    newdata = np.concatenate((newdata,dataset1),axis=0)
newdata = newdata[33600:,]
print(newdata.shape)
# Out:
# b (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# c (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# d (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# e (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# f (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# g (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# h (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# i (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# j (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# k (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# l (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# m (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# (403200, 5)

# %%
first_5_eigenworms = eigenworms[0:5,:]
eig_worm_0 = eigenworms[0,:]
eig_worm_1 = eigenworms[1,:]
eig_worm_2 = eigenworms[2,:]
eig_worm_3 = eigenworms[3,:]
eig_worm_4 = eigenworms[4,:]

# %%
data3=newdata[~np.isnan(newdata).any(axis=1)]
#d[:,~np.all(np.isnan(d), axis=0)]
#data3=footage[k].flatten()
data3 = data3.astype('float32')
print(data3.shape)
print(len(data3))
# Out:
# (386422, 5)
# 386422

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data3 = scaler.fit_transform(data3)

# %%
def create_dataset(dataset, look_back=3):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
data_X, data_Y = create_dataset(data3)

print(data_X.shape)
print(data_Y.shape)
# Out:
# (386419, 3, 5)
# (386419, 5)

# %%
train_size = int(len(data_X) * 0.8)
test_size = len(data_X) - train_size
train_X = data_X[:train_size]
train_Y = data_Y[:train_size]
test_X = data_X[train_size:]
test_Y = data_Y[train_size:]

print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (309135, 3, 5)
# (309135, 5)
# (77284, 3, 5)
# (77284, 5)

# %%
# reshape input to be [samples, time steps, features]
train_X = np.reshape(train_X, (train_X.shape[0], 5, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 5, test_X.shape[1]))

print(train_X.shape)
print(train_Y.shape)
# Out:
# (309135, 5, 3)
# (309135, 5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Input,LSTM,Dropout,Dense



# create and fit the LSTM network

model = keras.Sequential()
model.add(LSTM(260,input_shape=(5,3),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(260,input_shape=(5,3),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(260,input_shape=(5,3),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(260,input_shape=(5,3),return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(5,activation='linear'))
model.compile(optimizer='rmsprop',loss='mean_squared_error',metrics=['mape'])

history = model.fit(train_X, train_Y, epochs=50, batch_size=200, verbose=2)
# Out:
# Epoch 1/50
# 1546/1546 - 153s - loss: 0.0082 - mape: 620.4402
# Epoch 2/50
# 1546/1546 - 144s - loss: 0.0011 - mape: 175.5926
# Epoch 3/50
# 1546/1546 - 145s - loss: 7.6078e-04 - mape: 164.2044
# Epoch 4/50
# 1546/1546 - 142s - loss: 5.9344e-04 - mape: 140.6105
# Epoch 5/50
# 1546/1546 - 142s - loss: 4.8264e-04 - mape: 142.4186
# Epoch 6/50
# 1546/1546 - 142s - loss: 4.0641e-04 - mape: 35.4965
# Epoch 41/50
# 1546/1546 - 151s - loss: 1.7345e-04 - mape: 85.2510
# Epoch 42/50
# 1546/1546 - 151s - loss: 1.7207e-04 - mape: 123.7197
# Epoch 43/50
# 1546/1546 - 151s - loss: 1.7132e-04 - mape: 178.7272
# Epoch 44/50
# 1546/1546 - 148s - loss: 1.7009e-04 - mape: 44.0253
# Epoch 45/50
# 1546/1546 - 147s - loss: 1.6874e-04 - mape: 122.0445
# Epoch 46/50
# 1546/1546 - 148s - loss: 1.6862e-04 - mape: 53.7010
# Epoch 47/50
# 1546/1546 - 148s - loss: 1.6713e-04 - mape: 104.7710
# Epoch 48/50
# 1546/1546 - 147s - loss: 1.6660e-04 - mape: 119.5928
# Epoch 49/50
# 1546/1546 - 147s - loss: 1.6571e-04 - mape: 110.6163
# Epoch 50/50
# 1546/1546 - 149s - loss: 1.6488e-04 - mape: 92.6499

# %%
# make predictions
trainPredict = model.predict(train_X)
testPredict = model.predict(test_X)

# %%
print(testPredict.shape)
print(trainPredict.shape)
print(test_Y.shape)
# Out:
# (77284, 5)
# (309135, 5)
# (77284, 5)

# %%
def show_curve_plot(x, length, first_5_eigenworms, start=0, title="Plot", vmin=0, vmax=1, bar_pos=10):
    '''
    Function to plot curvature/time of an input array x (shape - (N,5)).
    '''
    START=start
    NUM_FRAMES=length
    x= np.array(x)
    q = np.sum(x[0].reshape(5,1)*first_5_eigenworms,axis=0)
    for j in range(NUM_FRAMES - 1):
        new_row = np.sum(x[START+j+1].reshape(5,1)*first_5_eigenworms,axis=0)
        q = np.vstack((q,new_row))
    plt.rcParams['figure.figsize'] = 20, 20
    plt.title(title)
    plt.yticks(np.arange(0, 100, 20.0))
    plt.xticks(np.arange(0, length, 100.0))
    plt.ylabel('Body Position (u)')
    plt.xlabel('Frame Number (16FPS)')
    print("QMin: " + str(q.min()) + " QMax: " + str(q.max()) + " QMean: " + str(q.mean()))
    plt.imshow(q.transpose(),cmap='viridis',vmin=vmin, vmax=vmax)
#     plt.axvline(x=bar_pos, ymin=0, ymax=100, linewidth=1, color='k')
    plt.gca().invert_yaxis()
    ax = plt.gca()
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(cax=cax)
    plt.show()

# %%
length = 2000
vmin = -0.65
vmax = 0.35
#3300
start = 3300
slc = slice(start,start+length)
start_of_test = 309135
show_curve_plot(testPredict[slc], length, first_5_eigenworms, 0,"Predicted Muscle Activations",vmin=vmin,vmax=vmax,bar_pos=start_of_test)
show_curve_plot(test_Y[slc], length,first_5_eigenworms, 0,"Real Muscle Activations",vmin=vmin,vmax=vmax,bar_pos=start_of_test)
#show_curve_plot(train_X[slc,0,0:5], length,first_5_eigenworms, start=0, title="Body Curvature",vmin=vmin,vmax=vmax,bar_pos=start_of_test)
# Out:
# QMin: -0.6066271358820309 QMax: 0.35964185765174655 QMean: 7.125411372044255e-18
# QMin: -0.6116551323420432 QMax: 0.3567047119292496 QMean: 7.187583861423264e-18

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("Mode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,length])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,10
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode Reconstruction")
    plt.show()
plot_coefficient_reconstruction(model, test_X[start:start+length], test_Y[start:start+length])

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("Mode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,77284])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,10
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode Reconstruction")
    plt.show()
plot_coefficient_reconstruction(model, test_X, test_Y)
