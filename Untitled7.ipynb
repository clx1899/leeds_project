# %%
from test import EigenData
import numpy as np
import scipy.io
import h5py
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import torch
# %matplotlib inline

# %%
data = EigenData()
eigenworms = data.get_eigenworms('EigenWorms.mat')

footage = data.get_footage('20150814-All-PNAS2011-DataStitched .mat')
newdata = torch.rand(33600,5)
for k in footage.keys():
    print(k, footage[k].shape)
    arr1=footage[k]

    arr2=arr1[:5,]

    r = data.reconstruct(footage[k])
    print('-->', r.shape)
    dataset1 = arr2.transpose()

    newdata = np.concatenate((newdata,dataset1),axis=0)
newdata = newdata[33600:,]
print(newdata.shape)
# Out:
# b (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# c (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# d (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# e (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# f (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# g (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# h (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# i (6, 33600)
# (100, 6) (6, 33600)
# --> (100, 33600)
# j (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# k (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# l (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# m (5, 33600)
# (100, 5) (5, 33600)
# --> (100, 33600)
# (403200, 5)

# %%
first_5_eigenworms = eigenworms[0:5,:]
eig_worm_0 = eigenworms[0,:]
eig_worm_1 = eigenworms[1,:]
eig_worm_2 = eigenworms[2,:]
eig_worm_3 = eigenworms[3,:]
eig_worm_4 = eigenworms[4,:]

# %%
data1=newdata[~np.isnan(newdata).any(axis=1)]
#d[:,~np.all(np.isnan(d), axis=0)]
#data3=footage[k].flatten()
data1 = data1.astype('float32')
print(data1.shape)
print(len(data1))
# Out:
# (386422, 5)
# 386422

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data1 = scaler.fit_transform(data1)

# %%
def create_dataset(dataset, look_back=5):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
data_X, data_Y = create_dataset(data1)

print(data_X.shape)
print(data_Y.shape)
# Out:
# (386417, 5, 5)
# (386417, 5)

# %%
train_size = int(len(data_X) * 0.8)
test_size = len(data_X) - train_size
train_X = data_X[:train_size]
train_Y = data_Y[:train_size]
test_X = data_X[train_size:]
test_Y = data_Y[train_size:]

print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (309133, 5, 5)
# (309133, 5)
# (77284, 5, 5)
# (77284, 5)

# %%
# reshape input to be [samples, time steps, features]
train_X = np.reshape(train_X, (train_X.shape[0], 5, train_X.shape[2]))
test_X = np.reshape(test_X, (test_X.shape[0], 5, test_X.shape[2]))

print(train_X.shape)
print(train_Y.shape)
# Out:
# (309133, 5, 5)
# (309133, 5)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Input,LSTM,Dropout,Dense



# create and fit the LSTM network

model = keras.Sequential()
model.add(LSTM(200,input_shape=(5,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200,input_shape=(5,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200,input_shape=(5,5),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200,input_shape=(5,5),return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(5,activation='linear'))
model.compile(optimizer='rmsprop',loss='mean_squared_error',metrics=['accuracy','mape'])

# %%
history = model.fit(train_X, train_Y, epochs=100, batch_size=500, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/100
# 495/495 - 84s - loss: 0.0144 - accuracy: 0.5701 - mape: 621.4123 - val_loss: 0.0044 - val_accuracy: 0.7899 - val_mape: 583.7252
# Epoch 2/100
# 495/495 - 76s - loss: 0.0036 - accuracy: 0.8139 - mape: 393.1251 - val_loss: 0.0014 - val_accuracy: 0.8759 - val_mape: 403.3826
# Epoch 3/100
# 495/495 - 77s - loss: 0.0019 - accuracy: 0.8796 - mape: 291.7578 - val_loss: 9.6164e-04 - val_accuracy: 0.9347 - val_mape: 37.8660
# Epoch 4/100
# 495/495 - 78s - loss: 0.0014 - accuracy: 0.8964 - mape: 237.2968 - val_loss: 6.6270e-04 - val_accuracy: 0.9097 - val_mape: 189.6978
# Epoch 5/100
# 495/495 - 77s - loss: 0.0012 - accuracy: 0.9033 - mape: 187.7533 - val_loss: 3.5496e-04 - val_accuracy: 0.9494 - val_mape: 57.0452
# Epoch 6/100
# 495/495 - 76s - loss: 0.0010 - accuracy: 0.9073 - mape: 150.9944 - val_loss: 4.2873e-04 - val_accuracy: 0.9411 - val_mape: 22.3560
# Epoch 7/100
# 495/495 - 77s - loss: 8.9721e-04 - accuracy: 0.9117 - mape: 83.8102 - val_loss: 4.4764e-04 - val_accuracy: 0.9478 - val_mape: 146.0523
# Epoch 8/100
# 495/495 - 77s - loss: 8.0997e-04 - accuracy: 0.9150 - mape: 193.7619 - val_loss: 3.9777e-04 - val_accuracy: 0.9306 - val_mape: 332.9422
# Epoch 9/100
# 495/495 - 77s - loss: 7.3895e-04 - accuracy: 0.9163 - mape: 64.3922 - val_loss: 3.0491e-04 - val_accuracy: 0.9179 - val_mape: 177.3791
# Epoch 10/100
# 495/495 - 77s - loss: 6.7984e-04 - accuracy: 0.9177 - mape: 164.7719 - val_loss: 4.5564e-04 - val_accuracy: 0.9448 - val_mape: 139.5751
# Epoch 11/100
# 495/495 - 76s - loss: 6.2726e-04 - accuracy: 0.9196 - mape: 139.6263 - val_loss: 2.6846e-04 - val_accuracy: 0.9412 - val_mape: 91.3259
# Epoch 12/100
# 495/495 - 76s - loss: 5.8252e-04 - accuracy: 0.9213 - mape: 152.1526 - val_loss: 1.6344e-04 - val_accuracy: 0.9462 - val_mape: 146.7126
# Epoch 13/100
# 495/495 - 77s - loss: 5.3792e-04 - accuracy: 0.9240 - mape: 95.0209 - val_loss: 2.0001e-04 - val_accuracy: 0.9122 - val_mape: 98.2631
# Epoch 14/100
# 495/495 - 76s - loss: 5.0475e-04 - accuracy: 0.9252 - mape: 84.8112 - val_loss: 2.0017e-04 - val_accuracy: 0.9321 - val_mape: 30.2304
# 495/495 - 79s - loss: 2.0739e-04 - accuracy: 0.9491 - mape: 127.5547 - val_loss: 5.2079e-05 - val_accuracy: 0.9785 - val_mape: 127.6004
# Epoch 94/100
# 495/495 - 78s - loss: 2.0781e-04 - accuracy: 0.9490 - mape: 32.3284 - val_loss: 6.3230e-05 - val_accuracy: 0.9703 - val_mape: 21.0755
# Epoch 95/100
# 495/495 - 78s - loss: 2.0727e-04 - accuracy: 0.9496 - mape: 132.4164 - val_loss: 5.5816e-05 - val_accuracy: 0.9826 - val_mape: 52.6065
# Epoch 96/100
# 495/495 - 80s - loss: 2.0621e-04 - accuracy: 0.9488 - mape: 154.1159 - val_loss: 5.5078e-05 - val_accuracy: 0.9730 - val_mape: 78.7902
# Epoch 97/100
# 495/495 - 77s - loss: 2.0594e-04 - accuracy: 0.9500 - mape: 46.7981 - val_loss: 6.0259e-05 - val_accuracy: 0.9679 - val_mape: 136.9836
# Epoch 98/100
# 495/495 - 80s - loss: 2.0522e-04 - accuracy: 0.9505 - mape: 100.5281 - val_loss: 6.9742e-05 - val_accuracy: 0.9730 - val_mape: 75.3578
# Epoch 99/100
# 495/495 - 80s - loss: 2.0442e-04 - accuracy: 0.9499 - mape: 49.0347 - val_loss: 6.6194e-05 - val_accuracy: 0.9787 - val_mape: 39.7907
# Epoch 100/100
# 495/495 - 81s - loss: 2.0374e-04 - accuracy: 0.9495 - mape: 83.2738 - val_loss: 5.3627e-05 - val_accuracy: 0.9778 - val_mape: 77.0385

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 200)            164800
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 200)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 200)            320800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 200)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 200)            320800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 200)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 200)               320800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 1005
# =================================================================
# Total params: 1,128,205
# Trainable params: 1,128,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=range(len(history.history['loss']))
plt.figure()
plt.plot(epochs,history.history['loss'],'b',label='Training loss')
plt.plot(epochs,history.history['val_loss'],'r',label='Validation val_loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
epochs=range(len(history.history['accuracy']))
plt.figure()
plt.plot(epochs,history.history['accuracy'],'b',label='Training accuracy')
plt.plot(epochs,history.history['val_accuracy'],'r',label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.show()

# %%
epochs=range(len(history.history['mape']))
plt.figure()
plt.plot(epochs,history.history['mape'],'b',label='Training mape')
plt.plot(epochs,history.history['val_mape'],'r',label='Validation mape')
plt.title('Training and Validation mape')
plt.legend()
plt.show()

# %%
trainPredict = model.predict(train_X)
testPredict = model.predict(test_X)

# %%
print(testPredict.shape)
print(trainPredict.shape)
print(test_Y.shape)
# Out:
# (77284, 5)
# (309133, 5)
# (77284, 5)

# %%
length = 2500
vmin = -0.65
vmax = 0.35
#3300
start = 5000
slc = slice(start,start+length)
start_of_test = 309133

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("EigenMode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,length])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,20
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode")
    plt.show()
plot_coefficient_reconstruction(model, test_X[start:start+length], test_Y[start:start+length])

# %%
def plot_coefficient_reconstruction(model, X, Y):
    plt.clf()
    fig, axarr = plt.subplots(5, 1)
    for coeff_idx in range(7):
        if(coeff_idx == 0):
            i = 0
        elif(coeff_idx == 1):
            i = 1
        elif(coeff_idx == 2):
            i = 2
        elif(coeff_idx == 3):
            i = 3
        elif(coeff_idx == 4):
            i = 4
        else:
            break
        s=1.
        lw = .8
        MAX = 100000
        #print(X.shape)
        prediction_raw_sample = model.predict(X)[0:MAX][:,coeff_idx]
        Y_raw_sample = Y[0:MAX][:,coeff_idx]
        predictions = prediction_raw_sample

        #print(predictions.shape)
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), (predictions), s=s, label="Prediction")
        #plt.scatter(np.arange(0,Y_raw_sample.shape[0],1), Y_raw_sample[0:], s=s, label="Real")
        axarr[i].plot((predictions), label="Predicted", c="red", linewidth=lw)
        axarr[i].plot(Y_raw_sample[:], label="Data", linewidth=lw)
        axarr[i].title.set_text("Mode " + str(coeff_idx+1))
        axarr[i].set_ylim([0,1])
        axarr[i].set_xlim([0,38642])
        axarr[i].set_xlabel("Frame Number (16FPS)")
        axarr[i].set_ylabel("Coefficient")
        axarr[i].axvline(x=start_of_test, ymin=0, ymax=100, linewidth=1, color='k')


#         axarr[i,j].legend(loc="upper right")
        axarr[i].legend(fontsize=10,bbox_to_anchor=(1, 1),loc='center')
#     plt.figlegend( )
    plt.rcParams['figure.figsize'] = 10,10
    plt.tight_layout(pad=2.0)
    plt.suptitle("Eigemode Reconstruction")
    plt.show()
plot_coefficient_reconstruction(model, test_X, test_Y)
